# %%
#importing Kaggle library to fetch the data from kaggle using Kaggle API
import kaggle
# !kaggle datasets download shivamb/netflix-shows -f netflix_titles.csv
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/shivamb/netflix-shows
# License(s): CC0-1.0
# ...
#   0%|          | 0.00/1.34M [00:00<?, ?B/s]
#  75%|#######4  | 1.00M/1.34M [00:00<00:00, 5.06MB/s]
# 100%|##########| 1.34M/1.34M [00:00<00:00, 5.87MB/s]

# %%
#Unzip the file
import zipfile
zip_ref=zipfile.ZipFile('netflix_titles.csv.zip')
zip_ref.extractall()
zip_ref.close()

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Manikanta Sirana\API's\Kaggle API\netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
import sqlalchemy as sql
# You guys need to fix the sql server driver by going to ODBC 64 bit if we it is not exists try to sql one with your server name.
engine=sql.create_engine('mssql://Manikanta\SQLEXPRESS/project?driver=SQL+SERVER')
conn=engine.connect()

# %%
#tryibg to store data from dataframe to Sql database
df.to_sql('nteflix_raw',con=conn,index=False,if_exists='replace')

# %%
len(df)
# Out:
# 8807

# %%
# since in Sql server we are tring to send structure of the table with out table created earlier. 
#It gives random sizes and differnt sizes. So we need to make sure we create a table stucture earlier as we need.
#then again append data to empty table to SQL server

# %%
"""" below is the updated table structure created 
CREATE TABLE [dbo].[nteflix_raw](
	[show_id] [varchar](10) NULL,
	[type] [varchar](10) NULL,
	[title] [nvarchar](200) NULL,
	[director] [varchar](250) NULL,
	[cast] [varchar](1000) NULL,
	[country] [varchar](150) NULL,
	[date_added] [varchar](20) NULL,
	[release_year] int NULL,
	[rating] [varchar](10) NULL,
	[duration] [varchar](10) NULL,
	[listed_in] [varchar](100) NULL,
	[description] [varchar](500) NULL
)"""
# Out:
# '" below is the updated table structure created \nCREATE TABLE [dbo].[nteflix_raw](\n\t[show_id] [varchar](10) NULL,\n\t[type] [varchar](10) NULL,\n\t[title] [nvarchar](200) NULL,\n\t[director] [varchar](250) NULL,\n\t[cast] [varchar](1000) NULL,\n\t[country] [varchar](150) NULL,\n\t[date_added] [varchar](20) NULL,\n\t[release_year] int NULL,\n\t[rating] [varchar](10) NULL,\n\t[duration] [varchar](10) NULL,\n\t[listed_in] [varchar](100) NULL,\n\t[description] [varchar](500) NULL\n)'

# %%
# created the strcuture in mssql and we are appending to empty table again from notebook

# %%
df.to_sql('netflix_raw',con=conn,index=False,if_exists='append')
conn.close()

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df[df.show_id=='s5023']# see title is in japanese by making to nvarchar in sql it handles foreign languages
# Out:
#      show_id   type    title       director           cast      country  \
# 5022   s5023  Movie  반드시 잡는다  Hong-seon Kim  Baek Yoon-sik  South Korea
#
#              date_added  release_year rating duration  \
# 5022  February 28, 2018          2017  TV-MA  110 min
#
#                                     listed_in  \
# 5022  Dramas, International Movies, Thrillers
#
#                                             description
# 5022  After people in his town start turning up dead...

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64
